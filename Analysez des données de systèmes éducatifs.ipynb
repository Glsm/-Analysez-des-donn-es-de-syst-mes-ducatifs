# %% [markdown]
# # Import des librairies

# %%
import pandas as pd
import numpy as np

import seaborn as sns 
import os

import matplotlib as mpl
import matplotlib.pyplot as plt
pd.set_option('display.max_column',999)
pd.set_option('display.max_row',999)
np.set_printoptions(threshold=5)

# %%
path_to_file = '/Users/gulsumkapanoglu/Desktop/Edstats_csv/'

# %% [markdown]
# # Import des données

# %%
all_data=pd.read_csv(path_to_file + 'EdStatsData.csv')
footnotes=pd.read_csv(path_to_file +  'EdStatsFootNote.csv')
series=pd.read_csv(path_to_file +  'EdStatsSeries.csv')
countryseries=pd.read_csv( path_to_file+  'EdStatsCountry-Series.csv')
country=pd.read_csv(path_to_file +  'EdStatsCountry.csv')

# %% [markdown]
# # Décrire les informations contenues dans le jeu de données

# %%
all_data.shape
# Out:
# (886930, 70)

# %%
all_data.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name  Indicator Code  \
# 0  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2
# 1  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F
# 2  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI
# 3  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.M
# 4  Adjusted net enrolment rate, primary, both sex...     SE.PRM.TENR
#
#         1970       1971       1972       1973       1974      1975       1976  \
# 0        NaN        NaN        NaN        NaN        NaN       NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN       NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN       NaN        NaN
# ...

# %%
all_data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
#        '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2020', '2025', '2030', '2035', '2040', '2045',
#        '2050', '2055', '2060', '2065', '2070', '2075', '2080', '2085', '2090',
#        '2095', '2100', 'Unnamed: 69'],
#       dtype='object')

# %%
footnotes.head()
# Out:
#   CountryCode      SeriesCode    Year          DESCRIPTION  Unnamed: 4
# 0         ABW  SE.PRE.ENRL.FE  YR2001  Country estimation.         NaN
# 1         ABW  SE.TER.TCHR.FE  YR2005  Country estimation.         NaN
# 2         ABW  SE.PRE.TCHR.FE  YR2000  Country estimation.         NaN
# 3         ABW  SE.SEC.ENRL.GC  YR2004  Country estimation.         NaN
# 4         ABW     SE.PRE.TCHR  YR2006  Country estimation.         NaN

# %%
footnotes.columns
# Out:
# Index(['CountryCode', 'SeriesCode', 'Year', 'DESCRIPTION', 'Unnamed: 4'], dtype='object')

# %%
series.head()
# Out:
#            Series Code       Topic  \
# 0  BAR.NOED.1519.FE.ZS  Attainment
# 1     BAR.NOED.1519.ZS  Attainment
# 2  BAR.NOED.15UP.FE.ZS  Attainment
# 3     BAR.NOED.15UP.ZS  Attainment
# 4  BAR.NOED.2024.FE.ZS  Attainment
#
#                                       Indicator Name  \
# 0  Barro-Lee: Percentage of female population age...
# 1  Barro-Lee: Percentage of population age 15-19 ...
# 2  Barro-Lee: Percentage of female population age...
# 3  Barro-Lee: Percentage of population age 15+ wi...
# 4  Barro-Lee: Percentage of female population age...
#
#                                     Short definition  \
# 0  Percentage of female population age 15-19 with...
# 1  Percentage of population age 15-19 with no edu...
# 2  Percentage of female population age 15+ with n...
# 3  Percentage of population age 15+ with no educa...
# 4  Percentage of female population age 20-24 with...
#
#                                      Long definition  Unit of measure  \
# ...

# %%
series.columns
# Out:
# Index(['Series Code', 'Topic', 'Indicator Name', 'Short definition',
#        'Long definition', 'Unit of measure', 'Periodicity', 'Base Period',
#        'Other notes', 'Aggregation method', 'Limitations and exceptions',
#        'Notes from original source', 'General comments', 'Source',
#        'Statistical concept and methodology', 'Development relevance',
#        'Related source links', 'Other web links', 'Related indicators',
#        'License Type', 'Unnamed: 20'],
#       dtype='object')

# %%
countryseries.head()
# Out:
#   CountryCode         SeriesCode  \
# 0         ABW        SP.POP.TOTL
# 1         ABW        SP.POP.GROW
# 2         AFG        SP.POP.GROW
# 3         AFG  NY.GDP.PCAP.PP.CD
# 4         AFG        SP.POP.TOTL
#
#                                          DESCRIPTION  Unnamed: 3
# 0  Data sources : United Nations World Population...         NaN
# 1  Data sources: United Nations World Population ...         NaN
# 2  Data sources: United Nations World Population ...         NaN
# 3                 Estimates are based on regression.         NaN
# 4  Data sources : United Nations World Population...         NaN

# %%
countryseries.columns
# Out:
# Index(['CountryCode', 'SeriesCode', 'DESCRIPTION', 'Unnamed: 3'], dtype='object')

# %%
country.head()
# Out:
#   Country Code   Short Name   Table Name                     Long Name  \
# 0          ABW        Aruba        Aruba                         Aruba
# 1          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2          AGO       Angola       Angola   People's Republic of Angola
# 3          ALB      Albania      Albania           Republic of Albania
# 4          AND      Andorra      Andorra       Principality of Andorra
#
#   2-alpha code   Currency Unit  \
# 0           AW   Aruban florin
# 1           AF  Afghan afghani
# 2           AO  Angolan kwanza
# 3           AL    Albanian lek
# 4           AD            Euro
#
#                                        Special Notes  \
# 0  SNA data for 2000-2011 are updated from offici...
# 1  Fiscal year end: March 20; reporting period fo...
# 2  April 2013 database update: Based on IMF data,...
# 3                                                NaN
# 4                                                NaN
#
# ...

# %%
country.columns
# Out:
# Index(['Country Code', 'Short Name', 'Table Name', 'Long Name', '2-alpha code',
#        'Currency Unit', 'Special Notes', 'Region', 'Income Group', 'WB-2 code',
#        'National accounts base year', 'National accounts reference year',
#        'SNA price valuation', 'Lending category', 'Other groups',
#        'System of National Accounts', 'Alternative conversion factor',
#        'PPP survey year', 'Balance of Payments Manual in use',
#        'External debt Reporting status', 'System of trade',
#        'Government Accounting concept', 'IMF data dissemination standard',
#        'Latest population census', 'Latest household survey',
#        'Source of most recent Income and expenditure data',
#        'Vital registration complete', 'Latest agricultural census',
#        'Latest industrial data', 'Latest trade data',
#        'Latest water withdrawal data', 'Unnamed: 31'],
#       dtype='object')

# %%
def percentage(value):
    
    return "{0:.1f}%".format(value * 100)


files_description = pd.DataFrame(columns = ["Nb lignes", "Nb colonnes", "Taux remplissage moyen"] ,
                                 
                                 index = ["EdStatsData.csv", 
                                          'EdStatsFootNote.csv', 
                                          'EdStatsSeries.csv', 
                                          'EdStatsCountry-Series.csv', 
                                          'EdStatsCountry.csv'])

files_description["Nb lignes"] = [
    len(all_data.index),
    len(footnotes.index),
    len(series.index),
    len(countryseries.index),
    len(country.index)
]
                                            
files_description["Nb colonnes"] = [
    len(all_data.columns),
    len(footnotes.columns),
    len(series.columns),
    len(countryseries.columns),
    len(country.columns)
]

files_description["Taux remplissage moyen"] = [
    percentage(all_data.notna().mean().mean()),
    percentage(footnotes.notna().mean().mean()),
    percentage(series.notna().mean().mean()),
    percentage(countryseries.notna().mean().mean()),
    percentage(country.notna().mean().mean())
]



     

files_description
# Out:
#                            Nb lignes  Nb colonnes Taux remplissage moyen
# EdStatsData.csv               886930           70                  13.9%
# EdStatsFootNote.csv           643638            5                  80.0%
# EdStatsSeries.csv               3665           21                  28.3%
# EdStatsCountry-Series.csv        613            4                  75.0%
# EdStatsCountry.csv               241           32                  69.5%

# %% [markdown]
# # Pour plus de détails

# %%
all_data.info()

nb_row=all_data.shape[0]

percentage=all_data.apply(lambda x:(x.notna().sum()/nb_row)*100)


columns=all_data.columns

plt.figure(figsize=(20,8))
plt.xticks(rotation=90)

sns.barplot(x=columns,y=percentage)

plt.title('Pourcentage de remplissage par colonnes')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886930 entries, 0 to 886929
# Data columns (total 70 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Country Name    886930 non-null  object
#  1   Country Code    886930 non-null  object
#  2   Indicator Name  886930 non-null  object
#  3   Indicator Code  886930 non-null  object
#  4   1970            72288 non-null   float64
#  5   1971            35537 non-null   float64
#  6   1972            35619 non-null   float64
#  7   1973            35545 non-null   float64
#  8   1974            35730 non-null   float64
#  9   1975            87306 non-null   float64
#  10  1976            37483 non-null   float64
#  11  1977            37574 non-null   float64
#  12  1978            37576 non-null   float64
#  13  1979            36809 non-null   float64
#  14  1980            89122 non-null   float64
#  15  1981            38777 non-null   float64
# ...

# %% [markdown]
# # Suppresion des doublons

# %% [markdown]
# Là, on comprend qu'il n'y a pas de dublons car même nombre.

# %%
all_data.drop_duplicates()
print(all_data.shape)
# Out:
# (886930, 70)

# %% [markdown]
# # Sélectionner les informations qui semblent pertinentes pour répondre à la problématique

# %%
filled_column=all_data.apply(lambda x: True if (x.notna().sum()/nb_row)*100 > 12 else False)
colonne=filled_column.index
values=filled_column.values
selected_colonnes=colonne[values]

all_data=all_data[selected_colonnes]

# %%
indicator=all_data['Indicator Name'].unique()
nb_indicator=len(indicator)
country_=all_data['Country Name'].unique()
nb_country=len(country_)


print('Nombre d indicateurs : ')
print(nb_indicator)
print('Nombre de pays : ')
print(nb_country)

nb_country*nb_indicator==nb_row
indicator.tolist()
# Out:
# Nombre d indicateurs :
# 3665
# Nombre de pays :
# 242
# ['Adjusted net enrolment rate, lower secondary, both sexes (%)',
#  'Adjusted net enrolment rate, lower secondary, female (%)',
#  'Adjusted net enrolment rate, lower secondary, gender parity index (GPI)',
#  'Adjusted net enrolment rate, lower secondary, male (%)',
#  'Adjusted net enrolment rate, primary, both sexes (%)',
#  'Adjusted net enrolment rate, primary, female (%)',
#  'Adjusted net enrolment rate, primary, gender parity index (GPI)',
#  'Adjusted net enrolment rate, primary, male (%)',
#  'Adjusted net enrolment rate, upper secondary, both sexes (%)',
#  'Adjusted net enrolment rate, upper secondary, female (%)',
#  'Adjusted net enrolment rate, upper secondary, gender parity index (GPI)',
#  'Adjusted net enrolment rate, upper secondary, male (%)',
#  'Adjusted net intake rate to Grade 1 of primary education, both sexes (%)',
#  'Adjusted net intake rate to Grade 1 of primary education, female (%)',
# ...

# %% [markdown]
# On a vu qu'il existe 3665 indicateurs et que 242 pays

# %% [markdown]
# # Suppression des indicateurs inutiles

# %%
indicateurs_supprimés ='male|Male|primary|Primary|non-tertiary|teacher|Teacher|SABER|EGRA|PIAAC|PISA|LLECE|PASEC|TIMSS|SACMEQ|PIRLS'
filter1_data = all_data.drop(all_data[all_data['Indicator Name'].str.contains(indicateurs_supprimés)].index) 

print(len(filter1_data['Indicator Name'].unique().tolist()))
filter1_data['Indicator Name'].unique().tolist()
# Out:
# 677
# ['Adjusted net enrolment rate, lower secondary, both sexes (%)',
#  'Adjusted net enrolment rate, lower secondary, gender parity index (GPI)',
#  'Adjusted net enrolment rate, upper secondary, both sexes (%)',
#  'Adjusted net enrolment rate, upper secondary, gender parity index (GPI)',
#  'Adult illiterate population, 15+ years, both sexes (number)',
#  'Adult literacy rate, population 15+ years, both sexes (%)',
#  'Adult literacy rate, population 15+ years, gender parity index (GPI)',
#  'Africa Dataset: Percentage of lower secondary schools with access to electricity (%)',
#  'Africa Dataset: Percentage of lower secondary schools with access to potable water (%)',
#  'Africa Dataset: Percentage of lower secondary schools with mixed-sex toilets (%)',
#  'Africa Dataset: Percentage of lower secondary schools with no information on electricity (%)',
#  'Africa Dataset: Percentage of lower secondary schools with no information on potable water (%)',
# ...

# %% [markdown]
# # Les indicateurs qui nous intéressent

# %%
choosen_indicators= 'GDP|age 15-19|age 20-24|Population, ages 15-24, total|Population of the official age for secondary education, both sexes (number)|Population of the official age for tertiary education, both sexes (number)|computers|Gross enrolment ratio, secondary, both sexes (%)|Gross enrolment ratio, secondary, gender parity index (GPI)|Gross enrolment ratio, tertiary, both sexes (%)|Gross enrolment ratio, tertiary, gender parity index (GPI)|DHS: Secondary completion rate|Enrolment in tertiary education per 100,000 inhabitants, both sexes|Internet users'
filter2_data=pd.DataFrame()
filter2_data=filter2_data.append(filter1_data[filter1_data['Indicator Name'].str.contains(choosen_indicators)],ignore_index=True)
print(len(filter2_data['Indicator Name'].unique().tolist()))
filter2_data['Indicator Name'].unique().tolist()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/strings.py:1952: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# 64
# ['Barro-Lee: Average years of secondary schooling, age 15-19, total',
#  'Barro-Lee: Average years of secondary schooling, age 20-24, total',
#  'Barro-Lee: Average years of tertiary schooling, age 15-19, total',
#  'Barro-Lee: Average years of tertiary schooling, age 20-24, total',
#  'Barro-Lee: Average years of total schooling, age 15-19, total',
#  'Barro-Lee: Average years of total schooling, age 20-24, total',
#  'Barro-Lee: Percentage of population age 15-19 with no education',
#  'Barro-Lee: Percentage of population age 15-19 with secondary schooling. Completed Secondary',
#  'Barro-Lee: Percentage of population age 15-19 with secondary schooling. Total (Incomplete and Completed Secondary)',
# ...

# %% [markdown]
# # Percentage des indicators

# %%
nb_col=filter2_data.shape[1]
filter2_data.set_index(['Indicator Name'])
filter2_data['choosen'] = filter2_data.apply(lambda x:(x.notna().sum()/nb_col*100),axis=1)

# %%
filter2_data.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  1990  \
# 0  Barro-Lee: Average years of secondary schoolin...  BAR.SEC.SCHL.1519   NaN
# 1  Barro-Lee: Average years of secondary schoolin...  BAR.SEC.SCHL.2024   NaN
# 2  Barro-Lee: Average years of tertiary schooling...  BAR.TER.SCHL.1519   NaN
# 3  Barro-Lee: Average years of tertiary schooling...  BAR.TER.SCHL.2024   NaN
# 4  Barro-Lee: Average years of total schooling, a...      BAR.SCHL.1519   NaN
#
#    1995  1999  2000  2001  2002  2003  2004  2005  2006  2007  2008  2009  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %% [markdown]
# # Jointure entre Filter_data et Country

# %%
column_list = ['Country Code','Region','Income Group']
country_filter = country[column_list]
filter2_data=filter2_data.merge(country_filter,on='Country Code',how='left')

# %%
print(len(filter2_data['Indicator Name'].unique()))
print(len(filter2_data['Country Name'].unique()))
# Out:
# 64
# 242

# %%
filter2_data["choosen"].median()
# Out:
# 26.08695652173913

# %%
examine_par_pays=filter2_data.groupby(by=['Country Name','Region'])['choosen'].sum()/6400*100
examine_par_pays=pd.DataFrame(examine_par_pays)
examine_par_pays.reset_index(inplace=True)
examine_par_pays
# Out:
#                        Country Name                      Region    choosen
# 0                       Afghanistan                  South Asia  35.122283
# 1                           Albania       Europe & Central Asia  42.391304
# 2                           Algeria  Middle East & North Africa  41.847826
# 3                    American Samoa         East Asia & Pacific  21.263587
# 4                           Andorra       Europe & Central Asia  30.366848
# 5                            Angola          Sub-Saharan Africa  32.404891
# 6               Antigua and Barbuda   Latin America & Caribbean  31.589674
# 7                         Argentina   Latin America & Caribbean  50.135870
# 8                           Armenia       Europe & Central Asia  45.448370
# 9                             Aruba   Latin America & Caribbean  30.298913
# 10                        Australia         East Asia & Pacific  47.350543
# ...

# %%
filter2_data["choosen"].describe().T
# Out:
# count    15488.000000
# mean        38.762408
# std         28.068845
# min         17.391304
# 25%         17.391304
# 50%         26.086957
# 75%         39.130435
# max        100.000000
# Name: choosen, dtype: float64

# %%
plt.subplots(figsize=(13,7))

sns.barplot(x = 'Region', y = 'choosen', data= examine_par_pays)
plt.xticks(rotation=75)
plt.axhline(y=39, color='red')
plt.show()

# %%
pays_selectionnes=examine_par_pays[examine_par_pays['choosen']>40]
pays_selectionnes=pays_selectionnes['Country Name']

pays_selectionnes;

# %%
pays_selectionnes.unique().tolist()
# Out:
# ['Albania',
#  'Algeria',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bolivia',
#  'Botswana',
#  'Brazil',
#  'Bulgaria',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Central African Republic',
#  'Chile',
#  'China',
#  'Colombia',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt, Arab Rep.',
#  'El Salvador',
#  'Estonia',
#  'Finland',
#  'France',
#  'Gambia, The',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Guatemala',
#  'Guyana',
#  'Honduras',
#  'Hong Kong SAR, China',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran, Islamic Rep.',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Korea, Rep.',
#  'Kuwait',
#  'Kyrgyz Republic',
# ...

# %%
region_selectionnes=examine_par_pays[examine_par_pays['choosen']>40]
region_selectionnes=region_selectionnes['Region']

region_selectionnes;

# %%
region_selectionnes.unique().tolist()
# Out:
# ['Europe & Central Asia',
#  'Middle East & North Africa',
#  'Latin America & Caribbean',
#  'East Asia & Pacific',
#  'South Asia',
#  'Sub-Saharan Africa',
#  'North America']

# %%
f, axes = plt.subplots(4,2, figsize=(20,15))
plt.subplots_adjust(hspace=3)


reg=examine_par_pays.Region.unique()
c1=sns.barplot(x=examine_par_pays[examine_par_pays.Region==reg[0]]['Country Name'],
               y=examine_par_pays[examine_par_pays.Region==reg[0]]['choosen'],ax=axes[0,0])

c2=sns.barplot(x=examine_par_pays[examine_par_pays.Region==reg[1]]['Country Name'],
               y=examine_par_pays[examine_par_pays.Region==reg[1]]['choosen'],ax=axes[1,0])
c3=sns.barplot(x=examine_par_pays[examine_par_pays.Region==reg[2]]['Country Name'],
               y=examine_par_pays[examine_par_pays.Region==reg[2]]['choosen'],ax=axes[2,0])
c4=sns.barplot(x=examine_par_pays[examine_par_pays.Region==reg[3]]['Country Name'],
               y=examine_par_pays[examine_par_pays.Region==reg[3]]['choosen'],ax=axes[0,1])
c5=sns.barplot(x=examine_par_pays[examine_par_pays.Region==reg[4]]['Country Name'],
               y=examine_par_pays[examine_par_pays.Region==reg[4]]['choosen'],ax=axes[1,1])
c6=sns.barplot(x=examine_par_pays[examine_par_pays.Region==reg[5]]['Country Name'],
               y=examine_par_pays[examine_par_pays.Region==reg[5]]['choosen'],ax=axes[2,1])
c7=sns.barplot(x=examine_par_pays[examine_par_pays.Region==reg[6]]['Country Name'],
               y=examine_par_pays[examine_par_pays.Region==reg[6]]['choosen'],ax=axes[3,0])

plt.setp(c1.xaxis.get_majorticklabels(), rotation=90)
plt.setp(c2.xaxis.get_majorticklabels(), rotation=90)
plt.setp(c3.xaxis.get_majorticklabels(), rotation=90)
plt.setp(c4.xaxis.get_majorticklabels(), rotation=90)
plt.setp(c5.xaxis.get_majorticklabels(), rotation=90)
plt.setp(c6.xaxis.get_majorticklabels(), rotation=90)
plt.setp(c7.xaxis.get_majorticklabels(), rotation=90)

c1.title.set_text(reg[0])
c2.title.set_text(reg[1])
c3.title.set_text(reg[2])
c4.title.set_text(reg[3])
c5.title.set_text(reg[4])
c6.title.set_text(reg[5])
c7.title.set_text(reg[6])

plt.show()

# %%
filter3_data=filter2_data[filter2_data['Country Name'].isin(pays_selectionnes)]
len(filter3_data['Country Name'].unique())
# Out:
# 133

# %%
examine_par_pays_ind=filter3_data.groupby(by='Indicator Name')['choosen'].sum()/13300*100
examine_par_pays_ind.to_frame()
# Out:
#                                                       choosen
# Indicator Name
# Barro-Lee: Average years of secondary schooling...  39.130435
# Barro-Lee: Average years of secondary schooling...  39.130435
# Barro-Lee: Average years of tertiary schooling,...  39.130435
# Barro-Lee: Average years of tertiary schooling,...  39.130435
# Barro-Lee: Average years of total schooling, ag...  39.130435
# Barro-Lee: Average years of total schooling, ag...  39.130435
# Barro-Lee: Percentage of population age 15-19 w...  39.130435
# Barro-Lee: Percentage of population age 15-19 w...  39.130435
# Barro-Lee: Percentage of population age 15-19 w...  39.130435
# Barro-Lee: Percentage of population age 15-19 w...  39.130435
# Barro-Lee: Percentage of population age 15-19 w...  39.130435
# Barro-Lee: Percentage of population age 20-24 w...  39.130435
# Barro-Lee: Percentage of population age 20-24 w...  39.130435
# Barro-Lee: Percentage of population age 20-24 w...  39.130435
# ...

# %%
filter3_data['choosen'].median()
# Out:
# 39.130434782608695

# %%
filter3_data['choosen'].mean()
# Out:
# 45.64502288329411

# %%
ind_list=examine_par_pays_ind[examine_par_pays_ind>39]
ind_list=ind_list.index.tolist()
ind_list
# Out:
# ['Barro-Lee: Average years of secondary schooling, age 15-19, total',
#  'Barro-Lee: Average years of secondary schooling, age 20-24, total',
#  'Barro-Lee: Average years of tertiary schooling, age 15-19, total',
#  'Barro-Lee: Average years of tertiary schooling, age 20-24, total',
#  'Barro-Lee: Average years of total schooling, age 15-19, total',
#  'Barro-Lee: Average years of total schooling, age 20-24, total',
#  'Barro-Lee: Percentage of population age 15-19 with no education',
#  'Barro-Lee: Percentage of population age 15-19 with secondary schooling. Completed Secondary',
#  'Barro-Lee: Percentage of population age 15-19 with secondary schooling. Total (Incomplete and Completed Secondary)',
#  'Barro-Lee: Percentage of population age 15-19 with tertiary schooling. Completed Tertiary',
#  'Barro-Lee: Percentage of population age 15-19 with tertiary schooling. Total (Incomplete and Completed Tertiary)',
#  'Barro-Lee: Percentage of population age 20-24 with no education',
# ...

# %% [markdown]
# # Déterminer des ordres de grandeurs des indicateurs statistiques classiques pour les différentes zones géographiques et pays du monde

# %% [markdown]
# ### Deuxième Sélection d'indicateurs
#
# ##### Internet users (per 100 people),Personal computers (per 100 people) :  La condition la plus importante pour l'éducation en ligne est possesion d'un ordinateur personnel et l'accès à Internet.
# ##### Pour Economique : GPD per capita; Cibler les pays à fort pouvoir d'achat
# ##### Pour Demographie et education : On retient les données concernant la tranche d'age des 15-24 car notre cible est les lycéens et étudiants

# %%
ind_to_keep='Barro-Lee: Percentage of population age 15-19 with secondary schooling. Completed Secondary|Barro-Lee: Percentage of population age 15-19 with tertiary schooling. Completed Tertiary|Barro-Lee: Percentage of population age 20-24 with secondary schooling. Completed Secondary|Barro-Lee: Percentage of population age 20-24 with tertiary schooling. Completed Tertiary'

filter_data=filter3_data[filter3_data['Indicator Name']=='GDP per capita, PPP (current international $)']
filter_data=filter_data.append(filter3_data[filter3_data['Indicator Name'].str.contains('Population, ages 15-24, total')],ignore_index=True)
filter_data=filter_data.append(filter3_data[filter3_data['Indicator Name'].str.contains('computers')],ignore_index=True)
filter_data=filter_data.append(filter3_data[filter3_data['Indicator Name'].str.contains('Internet users')],ignore_index=True)
filter_data=filter_data.append(filter3_data[filter3_data['Indicator Name'].str.contains(ind_to_keep)],ignore_index=True)


filter_data_indicator=filter_data['Indicator Name'].unique()
nb_filter_data_indicator=len(filter_data_indicator)
print(nb_filter_data_indicator)
print(filter_data_indicator.tolist())
final_data=filter_data
final_data
# Out:
# 8
# ['GDP per capita, PPP (current international $)', 'Population, ages 15-24, total', 'Personal computers (per 100 people)', 'Internet users (per 100 people)', 'Barro-Lee: Percentage of population age 15-19 with secondary schooling. Completed Secondary', 'Barro-Lee: Percentage of population age 15-19 with tertiary schooling. Completed Tertiary', 'Barro-Lee: Percentage of population age 20-24 with secondary schooling. Completed Secondary', 'Barro-Lee: Percentage of population age 20-24 with tertiary schooling. Completed Tertiary']
#      Country Name Country Code  \
# 0         Albania          ALB
# 1         Algeria          DZA
# 2       Argentina          ARG
# 3         Armenia          ARM
# 4       Australia          AUS
# ...           ...          ...
# 1059       Zambia          ZMB
# 1060     Zimbabwe          ZWE
# 1061     Zimbabwe          ZWE
# 1062     Zimbabwe          ZWE
# 1063     Zimbabwe          ZWE
#
# ...

# %%
f, ax = plt.subplots(figsize = (26,15))
sns.barplot(x = "Region", y = "choosen", hue = "Income Group", data = final_data);
color="salmon"

# %%
f, ax = plt.subplots(figsize = (26,15))
sns.barplot(x = "Region", y = "choosen", hue = "Indicator Name", data = final_data)
plt.xticks(rotation=75)
plt.axhline(y=45, color='red');

# %%
final_data.groupby(by=['Region','Country Name','Indicator Name']).agg({'2010': [ 'mean','median','std']})
# Out:
#                                                                                              2010  \
#                                                                                              mean
# Region              Country Name Indicator Name
# East Asia & Pacific Australia    Barro-Lee: Percentage of population age 15-19 w...  3.203000e+01
#                                  Barro-Lee: Percentage of population age 15-19 w...  0.000000e+00
#                                  Barro-Lee: Percentage of population age 20-24 w...  7.663000e+01
#                                  Barro-Lee: Percentage of population age 20-24 w...  0.000000e+00
#                                  GDP per capita, PPP (current international $)       3.919104e+04
# ...                                                                                           ...
# Sub-Saharan Africa  Zimbabwe     Barro-Lee: Percentage of population age 20-24 w...  1.900000e-01
# ...

# %%
final_data.reset_index(inplace = True)

# %%
final_data.groupby(by=['Region','Country Name','Indicator Name']).agg({'2015': [ 'mean','median','std']})
# Out:
#                                                                                              2015  \
#                                                                                              mean
# Region              Country Name Indicator Name
# East Asia & Pacific Australia    Barro-Lee: Percentage of population age 15-19 w...           NaN
#                                  Barro-Lee: Percentage of population age 15-19 w...           NaN
#                                  Barro-Lee: Percentage of population age 20-24 w...           NaN
#                                  Barro-Lee: Percentage of population age 20-24 w...           NaN
#                                  GDP per capita, PPP (current international $)       4.647593e+04
# ...                                                                                           ...
# Sub-Saharan Africa  Zimbabwe     Barro-Lee: Percentage of population age 20-24 w...           NaN
# ...

# %% [markdown]
# # Selection sur les pays riches

# %%
final_data['Income Group'].unique()
# Out:
# array(['Upper middle income', 'Lower middle income', 'High income: OECD',
#        'High income: nonOECD', 'Low income'], dtype=object)

# %%
values=['High income: nonOECD', 'High income: OECD']
final_data = final_data[final_data['Income Group'].isin(values)]

# %%
view = final_data.set_index(['Region','Income Group','Country Name']).sort_index()
view
# Out:
#                                                                       index  \
# Region                     Income Group         Country Name
# East Asia & Pacific        High income: OECD    Australia                 4
#                                                 Australia               137
#                                                 Australia               270
#                                                 Australia               403
#                                                 Australia               548
#                                                 Australia               549
#                                                 Australia               550
#                                                 Australia               551
#                                                 Japan                    57
#                                                 Japan                   190
# ...

# %%
len(final_data['Country Name'].unique())
# Out:
# 48

# %% [markdown]
# # Affectation de weight à chaque indicateur

# %%
final_data['Indicator Name'].unique()
# Out:
# array(['GDP per capita, PPP (current international $)',
#        'Population, ages 15-24, total',
#        'Personal computers (per 100 people)', ...,
#        'Barro-Lee: Percentage of population age 15-19 with tertiary schooling. Completed Tertiary',
#        'Barro-Lee: Percentage of population age 20-24 with secondary schooling. Completed Secondary',
#        'Barro-Lee: Percentage of population age 20-24 with tertiary schooling. Completed Tertiary'],
#       dtype=object)

# %% [markdown]
# ### Nous allons maintenant créer un score entre 1 et 3 pour noter les indicators

# %%
iw = np.array([['GDP per capita, PPP (current international $)',2],['Personal computers (per 100 people)',2],['Internet users (per 100 people)',2],['Population, ages 15-24, total',2],[ 'Barro-Lee: Percentage of population age 15-19 with secondary schooling. Completed Secondary',1],['Barro-Lee: Percentage of population age 15-19 with tertiary schooling. Completed Tertiary',1],['Barro-Lee: Percentage of population age 20-24 with secondary schooling. Completed Secondary',1],['Barro-Lee: Percentage of population age 20-24 with tertiary schooling. Completed Tertiary',1]])
indicator_weight = pd.DataFrame(iw, index = [1,2,3,4,5,6,7,8], columns = ['Indicator Name', 'weight'])
indicator_weight['weight'] = pd.to_numeric(indicator_weight['weight'])
indicator_weight
# Out:
#                                       Indicator Name  weight
# 1      GDP per capita, PPP (current international $)       2
# 2                Personal computers (per 100 people)       2
# 3                    Internet users (per 100 people)       2
# 4                      Population, ages 15-24, total       2
# 5  Barro-Lee: Percentage of population age 15-19 ...       1
# 6  Barro-Lee: Percentage of population age 15-19 ...       1
# 7  Barro-Lee: Percentage of population age 20-24 ...       1
# 8  Barro-Lee: Percentage of population age 20-24 ...       1

# %%
final_data=final_data.merge(indicator_weight,on='Indicator Name',how='left')
final_data=final_data.set_index(['Country Name'])
final_data=final_data.sort_values(by='Country Name')
final_data
# Out:
#                       index Country Code  \
# Country Name
# Australia                 4          AUS
# Australia               270          AUS
# Australia               551          AUS
# Australia               550          AUS
# Australia               137          AUS
# Australia               548          AUS
# Australia               403          AUS
# Australia               549          AUS
# Austria                 404          AUT
# Austria                   5          AUT
# Austria                 271          AUT
# Austria                 555          AUT
# Austria                 138          AUT
# Austria                 554          AUT
# Austria                 553          AUT
# Austria                 552          AUT
# Bahrain                 557          BHR
# Bahrain                 559          BHR
# Bahrain                 272          BHR
# Bahrain                 139          BHR
# Bahrain                 556          BHR
# ...

# %% [markdown]
# # Remplissage par colonnes dans le tableau filtré

# %%
nb_row=final_data.shape[0]
percentage=final_data.apply(lambda x:(x.notna().sum()/nb_row)*100)
columns=final_data.columns
plt.figure(figsize=(20,8))
plt.xticks(rotation=90)
plt.bar(columns,percentage,) 
plt.show()

# %% [markdown]
# # Sélectionner les informations qui semblent pertinentes pour répondre à la problématique

# %% [markdown]
# # Calcul d'un score pour chaque pays par année

# %%
result_temp=final_data.apply(lambda x: x*final_data['weight'] if x.dtype=='float64' else x)

# %%
score1=result_temp.groupby('Country Name').sum().apply(lambda x: x/12 if x.dtype=='float64' else x) 
col = ['Country Code','Region','Income Group']

score2=final_data[col].drop_duplicates()
score=score1.merge(score2,on='Country Name',how='left')
score
# Out:
#                       index          1990          1995          1999  \
# Country Name
# Australia              3012  4.584283e+05  4.533082e+05  4.406262e+05
# Austria                3032  1.986700e+05  1.737674e+05  1.639594e+05
# Bahrain                3052  1.710988e+04  2.054694e+04  2.381112e+04
# Barbados               3092  1.021830e+04  9.446155e+03  9.118678e+03
# Belgium                3112  2.353939e+05  2.178581e+05  2.101830e+05
# Canada                 3312  6.804803e+05  6.688362e+05  6.863439e+05
# Chile                  3352  4.130355e+05  4.030423e+05  4.113533e+05
# Croatia                3492  1.014554e+05  1.069723e+05  1.059056e+05
# Cyprus                 3532  1.923542e+04  1.882818e+04  2.115008e+04
# Czech Republic         3552  2.562766e+05  2.868949e+05  2.697024e+05
# Denmark                3572  1.304015e+05  1.200418e+05  1.085469e+05
# Estonia                3672  3.615469e+04  3.423191e+04  3.421115e+04
# ...

# %%
global_seuil = score['2015'].quantile([0.90]).at[0.90]
print(global_seuil)

selected_global_country=score[score['2015']>= global_seuil]

selected_global_country.reset_index(drop=False, inplace=True)

selected_global_country=selected_global_country.set_index(['Region','Income Group','Country Name'])['2015']

selected_global_country=selected_global_country.to_frame()

selected_global_country.sort_index(axis=0)

selected_global_country['degree']=selected_global_country['2015'].rank(method='max',ascending=False)

selected_global_country
# Out:
# 1276419.330180109
#                                                                        2015  \
# Region                Income Group         Country Name
# Europe & Central Asia High income: OECD    Germany             1.455109e+06
# East Asia & Pacific   High income: OECD    Japan               2.033034e+06
# Europe & Central Asia High income: nonOECD Russian Federation  2.447627e+06
#                       High income: OECD    United Kingdom      1.295623e+06
# North America         High income: OECD    United States       7.534010e+06
#
#                                                                degree
# Region                Income Group         Country Name
# Europe & Central Asia High income: OECD    Germany                4.0
# East Asia & Pacific   High income: OECD    Japan                  3.0
# Europe & Central Asia High income: nonOECD Russian Federation     2.0
#                       High income: OECD    United Kingdom         5.0
# ...

# %%
filter_seuil=score.groupby(by=['Region','Income Group','Country Name'])['2015'].quantile([0.90]).to_frame()
filter_seuil
# Out:
#                                                                                   2015
# Region                     Income Group         Country Name
# East Asia & Pacific        High income: OECD    Australia            0.9  4.935301e+05
#                                                 Japan                0.9  2.033034e+06
#                                                 Korea, Rep.          0.9  1.081845e+06
#                                                 New Zealand          0.9  1.088560e+05
#                            High income: nonOECD Hong Kong SAR, China 0.9  1.523163e+05
#                                                 Macao SAR, China     0.9  2.831354e+04
#                                                 Singapore            0.9  1.275819e+05
# Europe & Central Asia      High income: OECD    Austria              0.9  1.691334e+05
#                                                 Belgium              0.9  2.146101e+05
# ...

# %%
score.reset_index(drop=False, inplace=True)
filter_seuil=filter_seuil.rename(columns={'2015': 'seuil'})
col_list = ['Region','Income Group','Country Name','2015']
tomerge = score[col_list]
country_by_region_and_income=tomerge.merge(filter_seuil,on=['Region','Income Group'],how='left')
country_by_region_and_income=country_by_region_and_income[country_by_region_and_income['2015']>country_by_region_and_income['seuil']]
country_by_region_and_income=country_by_region_and_income.set_index(['Region','Income Group','Country Name'])
country_by_region_and_income=country_by_region_and_income.sort_index(axis = 0)
country_by_region_and_income['degree']=country_by_region_and_income.groupby(by=['Region'])['2015'].rank(method='max',ascending=False)

country_by_region_and_income
# Out:
#                                                                               2015  \
# Region                     Income Group         Country Name
# East Asia & Pacific        High income: OECD    Australia             4.935301e+05
#                                                 Japan                 2.033034e+06
#                                                 Japan                 2.033034e+06
#                                                 Japan                 2.033034e+06
#                                                 Korea, Rep.           1.081845e+06
#                                                 Korea, Rep.           1.081845e+06
#                            High income: nonOECD Hong Kong SAR, China  1.523163e+05
#                                                 Hong Kong SAR, China  1.523163e+05
#                                                 Singapore             1.275819e+05
# ...

# %%
selectionnes_pay=country_by_region_and_income[country_by_region_and_income['degree']>80]
selectionnes_pay=selectionnes_pay[['degree']]

selectionnes_pay;

# %%
main_country1 = selectionnes_pay.index.tolist()
main_country2 = selected_global_country.index.tolist()
main_country=[x[2] for x in main_country1]+[x[2] for x in main_country2]
main_country=list(set(main_country))
main_country
# Out:
# ['Estonia',
#  'Germany',
#  'Belgium',
#  'Luxembourg',
#  'Spain',
#  'Slovak Republic',
#  'Slovenia',
#  'United States',
#  'Japan',
#  'Greece',
#  'Netherlands',
#  'Czech Republic',
#  'Lithuania',
#  'Italy',
#  'Switzerland',
#  'Croatia',
#  'Norway',
#  'Denmark',
#  'Poland',
#  'Ireland',
#  'Latvia',
#  'Russian Federation',
#  'United Kingdom',
#  'Sweden',
#  'Austria',
#  'Portugal',
#  'Finland']

# %% [markdown]
# ## Quelle sera l’évolution de ce potentiel de clients ?

# %%
path_to_file = '/Users/gulsumkapanoglu/Desktop/Edstats_csv/'

# %%
all_data=pd.read_csv(path_to_file + 'EdStatsData.csv')

# %%
evolution=all_data[all_data['Country Name'].isin(main_country)]
evolution_ind=[
 'Wittgenstein Projection: Population age 15-19 in thousands by highest level of educational attainment. Post Secondary. Total',
 'Wittgenstein Projection: Population age 15-19 in thousands by highest level of educational attainment. Upper Secondary. Total',
 'Wittgenstein Projection: Population age 20-24 in thousands by highest level of educational attainment. Post Secondary. Total',
 'Wittgenstein Projection: Population age 20-24 in thousands by highest level of educational attainment. Upper Secondary. Total']
evolution=evolution[evolution['Indicator Name'].isin(evolution_ind)]
evolution=evolution.groupby(by=['Country Name']).sum()
nb_row=evolution.shape[0]
colonne=evolution.columns

values=[False if x==0 else True for x in np.count_nonzero(evolution, axis=0)]

selected_colonnes=colonne[values]
evolution=evolution[selected_colonnes]

evolution
# Out:
#                         2010      2015      2020      2025      2030  \
# Country Name
# Austria               527.92    541.97    502.04    491.78    489.37
# Belgium               806.00    842.68    851.38    897.38    936.37
# Croatia               389.82    344.26    322.95    299.97    303.19
# Czech Republic        935.95    861.36    709.70    758.02    870.26
# Denmark               260.77    301.91    305.62    302.77    308.88
# Estonia                99.04     73.46     63.99     70.42     80.48
# Finland               255.36    273.44    256.27    257.64    273.66
# Germany              4041.73   3632.60   3623.01   3395.40   3387.79
# Greece                773.64    764.27    779.54    833.22    880.56
# Ireland               367.74    380.14    406.53    456.28    510.28
# Italy                2905.84   3158.25   3165.75   3367.75   3527.67
# Japan                7819.93   7408.43   7322.35   7124.27   6941.13
# ...

# %%
evolutionT = evolution.T
evolutionT.index = evolutionT.index.astype(int)
evolutionT = evolutionT[evolutionT.index>=2010]

# %%
evolutionT.plot(figsize=(20,12))

# %% [markdown]
# ## Les Pays Prioritaires

# %%
country_by_region_and_income
# Out:
#                                                                               2015  \
# Region                     Income Group         Country Name
# East Asia & Pacific        High income: OECD    Australia             4.935301e+05
#                                                 Japan                 2.033034e+06
#                                                 Japan                 2.033034e+06
#                                                 Japan                 2.033034e+06
#                                                 Korea, Rep.           1.081845e+06
#                                                 Korea, Rep.           1.081845e+06
#                            High income: nonOECD Hong Kong SAR, China  1.523163e+05
#                                                 Hong Kong SAR, China  1.523163e+05
#                                                 Singapore             1.275819e+05
# ...

# %%
conclusions_conclusions=country_by_region_and_income.copy()
conclusions_conclusions=conclusions_conclusions.rename(columns={"seuil": "seuil by region and income", "degree": "degree by region and income"})
conclusions_conclusions["degree global"]= selected_global_country["degree"]
conclusions_conclusions
# Out:
#                                                                               2015  \
# Region                     Income Group         Country Name
# East Asia & Pacific        High income: OECD    Australia             4.935301e+05
#                                                 Japan                 2.033034e+06
#                                                 Japan                 2.033034e+06
#                                                 Japan                 2.033034e+06
#                                                 Korea, Rep.           1.081845e+06
#                                                 Korea, Rep.           1.081845e+06
#                            High income: nonOECD Hong Kong SAR, China  1.523163e+05
#                                                 Hong Kong SAR, China  1.523163e+05
#                                                 Singapore             1.275819e+05
# ...

# %%
conclusions_conclusions["degree by region and income"].median()
# Out:
# 121.0

# %%
filter_paysprio1=conclusions_conclusions[conclusions_conclusions['degree by region and income']>121]
filter_paysprio1=filter_paysprio1[['degree by region and income']]
filter_paysprio1=filter_paysprio1.drop_duplicates()
filter_paysprio1;

# %%
filter_paysprio1.reset_index(inplace = True)

# %%
filter_paysprio1
# Out:
#                    Region          Income Group     Country Name  \
# 0   Europe & Central Asia     High income: OECD          Austria
# 1   Europe & Central Asia     High income: OECD          Belgium
# 2   Europe & Central Asia     High income: OECD   Czech Republic
# 3   Europe & Central Asia     High income: OECD          Denmark
# 4   Europe & Central Asia     High income: OECD          Estonia
# 5   Europe & Central Asia     High income: OECD          Finland
# 6   Europe & Central Asia     High income: OECD           Greece
# 7   Europe & Central Asia     High income: OECD          Ireland
# 8   Europe & Central Asia     High income: OECD       Luxembourg
# 9   Europe & Central Asia     High income: OECD      Netherlands
# 10  Europe & Central Asia     High income: OECD           Norway
# 11  Europe & Central Asia     High income: OECD         Portugal
# 12  Europe & Central Asia     High income: OECD  Slovak Republic
# ...

# %%
f, ax = plt.subplots(figsize = (26,15))
sns.barplot(x = "Country Name", y = "degree by region and income",  data = filter_paysprio1)
plt.axhline(y=121, color='red')
plt.xticks(rotation=75);
